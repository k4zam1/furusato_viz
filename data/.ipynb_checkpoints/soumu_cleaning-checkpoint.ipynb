# %%
import pandas as pd
soumu = pd.read_csv("soumu.csv")

# %%
categorical = [
    "広報活動","呼びかけ","見直し","イベントPR","決済",
    "用途選択肢","分野","事業","クラウドファンディング","まちづくり・市民活動",
    "スポーツ・文化振興","健康・医療・福祉","環境・衛生","教育・人づくり",
    "子ども・子育て","地域・産業振興","観光・交流・定住促進","安心・安全・防災","災害支援・復興"
]
# nan -> 0
soumu[categorical] = soumu[categorical].fillna(0)
# nullを探す
soumu.isnull().count()
# Out:
# code            1788
# pref            1788
# city            1788
# 寄附件数            1788
# 寄附金額            1788
# 寄附件数_県外         1788
# 寄附金額_県外         1788
# 返礼品等の調達に係る費用    1788
# 返礼品等の送付に係る費用    1788
# 広報に係る費用         1788
# 決済等に係る費用        1788
# 事務に係る費用         1788
# その他費用           1788
# 広報活動            1788
# 呼びかけ            1788
# 見直し             1788
# イベントPR          1788
# 決済              1788
# 用途選択肢           1788
# 分野              1788
# 事業              1788
# クラウドファンディング     1788
# まちづくり・市民活動      1788
# スポーツ・文化振興       1788
# 健康・医療・福祉        1788
# 環境・衛生           1788
# 教育・人づくり         1788
# 子ども・子育て         1788
# 地域・産業振興         1788
# 観光・交流・定住促進      1788
# 安心・安全・防災        1788
# 災害支援・復興         1788
# dtype: int64

# %%
# cityがnullな行を削除
# 47都道府県あるのでnullの個数は1788-47 = 1741になる
soumu = soumu.dropna(axis=0,how="any")
soumu.isnull().count()
# Out:
# code            1741
# pref            1741
# city            1741
# 寄附件数            1741
# 寄附金額            1741
# 寄附件数_県外         1741
# 寄附金額_県外         1741
# 返礼品等の調達に係る費用    1741
# 返礼品等の送付に係る費用    1741
# 広報に係る費用         1741
# 決済等に係る費用        1741
# 事務に係る費用         1741
# その他費用           1741
# 広報活動            1741
# 呼びかけ            1741
# 見直し             1741
# イベントPR          1741
# 決済              1741
# 用途選択肢           1741
# 分野              1741
# 事業              1741
# クラウドファンディング     1741
# まちづくり・市民活動      1741
# スポーツ・文化振興       1741
# 健康・医療・福祉        1741
# 環境・衛生           1741
# 教育・人づくり         1741
# 子ども・子育て         1741
# 地域・産業振興         1741
# 観光・交流・定住促進      1741
# 安心・安全・防災        1741
# 災害支援・復興         1741
# dtype: int64

# %%
# ○を1に置き換える
soumu = soumu.replace("○",1)
soumu.head()
# Out:
#     code pref city     寄附件数            寄附金額  寄附件数_県外         寄附金額_県外  \
# 1  11002  北海道  札幌市   2,240     456,498,928    1,971     152,407,288
# 2  12025  北海道  函館市  43,753     579,858,782   43,731     578,548,782
# 3  12033  北海道  小樽市   7,346     152,107,270    7,314     136,765,320
# 4  12041  北海道  旭川市  81,238   1,313,436,740   80,996   1,279,668,006
# 5  12050  北海道  室蘭市   1,191      22,729,000    1,190      22,719,000
#
#    返礼品等の調達に係る費用 返礼品等の送付に係る費用     広報に係る費用  ... まちづくり・市民活動 スポーツ・文化振興 健康・医療・福祉  \
# 1    5,832,232    2,547,574     626,994   ...          1         1        1
# 2  170,738,610   93,315,640           0   ...          1         0        1
# 3   39,009,000   10,865,058     880,000   ...          0         0        0
# 4  380,109,521   59,678,465   6,099,360   ...          1         1        1
# 5    4,860,234    1,029,750           0   ...          0         1        1
#
#    環境・衛生  教育・人づくり  子ども・子育て  地域・産業振興  観光・交流・定住促進 安心・安全・防災  災害支援・復興
# 1      1        1        1        1           1        0        1
# 2      0        1        1        1           1        1        0
# 3      0        0        0        0           0        0        0
# 4      1        1        1        1           1        0        0
# 5      0        0        1        0           1        1        0
#
# [5 rows x 32 columns]

# %%
# nullを含む行を抽出してみる
soumu[soumu.isnull().any(axis=0)]
# Out:
# Empty DataFrame
# Columns: [code, pref, city, 寄附件数, 寄附金額, 寄附件数_県外, 寄附金額_県外, 返礼品等の調達に係る費用, 返礼品等の送付に係る費用, 広報に係る費用, 決済等に係る費用, 事務に係る費用, その他費用, 広報活動, 呼びかけ, 見直し, イベントPR, 決済, 用途選択肢, 分野, 事業, クラウドファンディング, まちづくり・市民活動, スポーツ・文化振興, 健康・医療・福祉, 環境・衛生, 教育・人づくり, 子ども・子育て, 地域・産業振興, 観光・交流・定住促進, 安心・安全・防災, 災害支援・復興]
# Index: []
#
# [0 rows x 32 columns]
